# %%
# !pip install xarray netCDF4 h5netcdf s3fs pandas matplotlib
# Out:
# Requirement already satisfied: xarray in /home/chou/anaconda3/lib/python3.12/site-packages (2023.6.0)
# Requirement already satisfied: netCDF4 in /home/chou/anaconda3/lib/python3.12/site-packages (1.7.3)
# Requirement already satisfied: h5netcdf in /home/chou/anaconda3/lib/python3.12/site-packages (1.7.3)
# Requirement already satisfied: s3fs in /home/chou/anaconda3/lib/python3.12/site-packages (2024.6.1)
# Requirement already satisfied: pandas in /home/chou/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: matplotlib in /home/chou/anaconda3/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: numpy>=1.21 in /home/chou/anaconda3/lib/python3.12/site-packages (from xarray) (1.26.4)
# Requirement already satisfied: packaging>=21.3 in /home/chou/anaconda3/lib/python3.12/site-packages (from xarray) (24.1)
# Requirement already satisfied: cftime in /home/chou/anaconda3/lib/python3.12/site-packages (from netCDF4) (1.6.5)
# Requirement already satisfied: certifi in /home/chou/anaconda3/lib/python3.12/site-packages (from netCDF4) (2024.8.30)
# Requirement already satisfied: h5py in /home/chou/anaconda3/lib/python3.12/site-packages (from h5netcdf) (3.11.0)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /home/chou/anaconda3/lib/python3.12/site-packages (from s3fs) (2.12.3)
# Requirement already satisfied: fsspec==2024.6.1.* in /home/chou/anaconda3/lib/python3.12/site-packages (from s3fs) (2024.6.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/chou/anaconda3/lib/python3.12/site-packages (from s3fs) (3.10.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/chou/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/chou/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/chou/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/chou/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/chou/anaconda3/lib/python3.12/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/chou/anaconda3/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/chou/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=8 in /home/chou/anaconda3/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/chou/anaconda3/lib/python3.12/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: botocore<1.34.70,>=1.34.41 in /home/chou/anaconda3/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.34.69)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /home/chou/anaconda3/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.14.1)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /home/chou/anaconda3/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (0.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/chou/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/chou/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/chou/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/chou/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/chou/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/chou/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.11.0)
# Requirement already satisfied: six>=1.5 in /home/chou/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: typing_extensions>=3.7 in /home/chou/anaconda3/lib/python3.12/site-packages (from aioitertools<1.0.0,>=0.5.1->aiobotocore<3.0.0,>=2.5.4->s3fs) (4.11.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/chou/anaconda3/lib/python3.12/site-packages (from botocore<1.34.70,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.0.1)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/chou/anaconda3/lib/python3.12/site-packages (from botocore<1.34.70,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.2.3)
# Requirement already satisfied: idna>=2.0 in /home/chou/anaconda3/lib/python3.12/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.7)
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/chou/anaconda3
#
#   added / updated specs:
#     - cartopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.11.12 |       hbd8a1cb_0         149 KB  conda-forge
#     cartopy-0.25.0             |  py312hf79963d_1         1.5 MB  conda-forge
#     certifi-2025.11.12         |     pyhd8ed1ab_0         153 KB  conda-forge
#     conda-24.11.3              |  py312h7900ff3_0         1.1 MB  conda-forge
#     geos-3.14.1                |       h480dda7_0         1.9 MB  conda-forge
#     libgcc-15.2.0              |      he0feb66_15        1017 KB  conda-forge
#     libgcc-ng-15.2.0           |      h69a702a_15          26 KB  conda-forge
#     libgomp-15.2.0             |      he0feb66_15         589 KB  conda-forge
#     libstdcxx-15.2.0           |      h934c35e_15         5.6 MB  conda-forge
#     libstdcxx-ng-15.2.0        |      hdf11a46_15          26 KB  conda-forge
#     openssl-3.6.0              |       h26f9b46_0         3.0 MB  conda-forge
#     proj-9.3.1                 |       he5811b7_0         3.2 MB
#     pyproj-3.6.1               |  py312h38f1c37_5         532 KB  conda-forge
#     pyshp-3.0.3                |     pyhd8ed1ab_0         444 KB  conda-forge
#     python_abi-3.12            |          3_cp312           6 KB
#     shapely-2.1.2              |  py312h383787d_2         617 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        19.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   cartopy            conda-forge/linux-64::cartopy-0.25.0-py312hf79963d_1
#   geos               conda-forge/linux-64::geos-3.14.1-h480dda7_0
#   libgcc             conda-forge/linux-64::libgcc-15.2.0-he0feb66_15
#   libstdcxx          conda-forge/linux-64::libstdcxx-15.2.0-h934c35e_15
#   proj               pkgs/main/linux-64::proj-9.3.1-he5811b7_0
#   pyproj             conda-forge/linux-64::pyproj-3.6.1-py312h38f1c37_5
#   pyshp              conda-forge/noarch::pyshp-3.0.3-pyhd8ed1ab_0
#   python_abi         pkgs/main/linux-64::python_abi-3.12-3_cp312
#   shapely            conda-forge/linux-64::shapely-2.1.2-py312h383787d_2
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2~ --> conda-forge/noarch::ca-certificates-2025.11.12-hbd8a1cb_0
#   certifi            pkgs/main/linux-64::certifi-2024.8.30~ --> conda-forge/noarch::certifi-2025.11.12-pyhd8ed1ab_0
#   conda              pkgs/main::conda-24.9.2-py312h06a4308~ --> conda-forge::conda-24.11.3-py312h7900ff3_0
#   libgcc-ng          pkgs/main::libgcc-ng-11.2.0-h1234567_1 --> conda-forge::libgcc-ng-15.2.0-h69a702a_15
#   libgomp              pkgs/main::libgomp-11.2.0-h1234567_1 --> conda-forge::libgomp-15.2.0-he0feb66_15
#   libstdcxx-ng       pkgs/main::libstdcxx-ng-11.2.0-h12345~ --> conda-forge::libstdcxx-ng-15.2.0-hdf11a46_15
#   openssl              pkgs/main::openssl-3.0.15-h5eee18b_0 --> conda-forge::openssl-3.6.0-h26f9b46_0
#
#
# Proceed ([y]/n)?
# CondaSystemExit:
# Operation aborted.  Exiting.
#
# ^C

# %%
# %conda install -c conda-forge cartopy
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/chou/anaconda3
#
#   added / updated specs:
#     - cartopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.11.12 |       hbd8a1cb_0         149 KB  conda-forge
#     cartopy-0.25.0             |  py312hf79963d_1         1.5 MB  conda-forge
#     certifi-2025.11.12         |     pyhd8ed1ab_0         153 KB  conda-forge
#     conda-24.11.3              |  py312h7900ff3_0         1.1 MB  conda-forge
#     geos-3.14.1                |       h480dda7_0         1.9 MB  conda-forge
#     libgcc-15.2.0              |      he0feb66_15        1017 KB  conda-forge
#     libgcc-ng-15.2.0           |      h69a702a_15          26 KB  conda-forge
#     libgomp-15.2.0             |      he0feb66_15         589 KB  conda-forge
#     libstdcxx-15.2.0           |      h934c35e_15         5.6 MB  conda-forge
#     libstdcxx-ng-15.2.0        |      hdf11a46_15          26 KB  conda-forge
#     openssl-3.6.0              |       h26f9b46_0         3.0 MB  conda-forge
#     proj-9.3.1                 |       he5811b7_0         3.2 MB
#     pyproj-3.6.1               |  py312h38f1c37_5         532 KB  conda-forge
#     pyshp-3.0.3                |     pyhd8ed1ab_0         444 KB  conda-forge
#     python_abi-3.12            |          3_cp312           6 KB
#     shapely-2.1.2              |  py312h383787d_2         617 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        19.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   cartopy            conda-forge/linux-64::cartopy-0.25.0-py312hf79963d_1
#   geos               conda-forge/linux-64::geos-3.14.1-h480dda7_0
#   libgcc             conda-forge/linux-64::libgcc-15.2.0-he0feb66_15
#   libstdcxx          conda-forge/linux-64::libstdcxx-15.2.0-h934c35e_15
#   proj               pkgs/main/linux-64::proj-9.3.1-he5811b7_0
#   pyproj             conda-forge/linux-64::pyproj-3.6.1-py312h38f1c37_5
#   pyshp              conda-forge/noarch::pyshp-3.0.3-pyhd8ed1ab_0
#   python_abi         pkgs/main/linux-64::python_abi-3.12-3_cp312
#   shapely            conda-forge/linux-64::shapely-2.1.2-py312h383787d_2
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2~ --> conda-forge/noarch::ca-certificates-2025.11.12-hbd8a1cb_0
#   certifi            pkgs/main/linux-64::certifi-2024.8.30~ --> conda-forge/noarch::certifi-2025.11.12-pyhd8ed1ab_0
#   conda              pkgs/main::conda-24.9.2-py312h06a4308~ --> conda-forge::conda-24.11.3-py312h7900ff3_0
#   libgcc-ng          pkgs/main::libgcc-ng-11.2.0-h1234567_1 --> conda-forge::libgcc-ng-15.2.0-h69a702a_15
#   libgomp              pkgs/main::libgomp-11.2.0-h1234567_1 --> conda-forge::libgomp-15.2.0-he0feb66_15
#   libstdcxx-ng       pkgs/main::libstdcxx-ng-11.2.0-h12345~ --> conda-forge::libstdcxx-ng-15.2.0-hdf11a46_15
#   openssl              pkgs/main::openssl-3.0.15-h5eee18b_0 --> conda-forge::openssl-3.6.0-h26f9b46_0
#
#
#
# Downloading and Extracting Packages:
# libstdcxx-15.2.0     | 5.6 MB    |                                       |   0%
# proj-9.3.1           | 3.2 MB    |                                       |   0%
#
# openssl-3.6.0        | 3.0 MB    |                                       |   0%
#
#
# geos-3.14.1          | 1.9 MB    |                                       |   0%
#
#
#
# cartopy-0.25.0       | 1.5 MB    |                                       |   0%
#
#
#
#
# conda-24.11.3        | 1.1 MB    |                                       |   0%
#
#
#
#
#
# libgcc-15.2.0        | 1017 KB   |                                       |   0%
#
#
#
#
#
#
# shapely-2.1.2        | 617 KB    |                                       |   0%
#
#
#
#
#
#
#
# libgomp-15.2.0       | 589 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 532 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# pyshp-3.0.3          | 444 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# certifi-2025.11.12   | 153 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-15.2.0  | 26 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.2.0     | 26 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.12      | 6 KB      |                                       |   0%
#
#
#
# libstdcxx-15.2.0     | 5.6 MB    | 1                                     |   0%
#
#
# geos-3.14.1          | 1.9 MB    | 3                                     |   1%
#
# openssl-3.6.0        | 3.0 MB    | 1                                     |   1%
# proj-9.3.1           | 3.2 MB    | 1                                     |   0%
#
#
#
# libstdcxx-15.2.0     | 5.6 MB    | #9                                    |   5%
#
#
# geos-3.14.1          | 1.9 MB    | ######1                               |  17%
# proj-9.3.1           | 3.2 MB    | ##1                                   |   6%
#
# libstdcxx-15.2.0     | 5.6 MB    | ###5                                  |  10%
#
#
# geos-3.14.1          | 1.9 MB    | ##########7                           |  29%
#
# openssl-3.6.0        | 3.0 MB    | #########                             |  24%
# proj-9.3.1           | 3.2 MB    | ####9                                 |  13%
#
#
#
# libstdcxx-15.2.0     | 5.6 MB    | #######8                              |  21%
#
#
# geos-3.14.1          | 1.9 MB    | ########################2             |  66%
#
# openssl-3.6.0        | 3.0 MB    | ##############3                       |  39%
# proj-9.3.1           | 3.2 MB    | #########1                            |  25%
#
#
#
# libstdcxx-15.2.0     | 5.6 MB    | ##########2                           |  28%
#
#
# geos-3.14.1          | 1.9 MB    | ##################################6   |  94%
# proj-9.3.1           | 3.2 MB    | #############5                        |  37%
#
# openssl-3.6.0        | 3.0 MB    | ####################6                 |  56%
#
#
#
# libstdcxx-15.2.0     | 5.6 MB    | ############4                         |  34%
# proj-9.3.1           | 3.2 MB    | #################3                    |  47%
#
# openssl-3.6.0        | 3.0 MB    | ##########################6           |  72%
#
#
#
# libstdcxx-15.2.0     | 5.6 MB    | #################4                    |  47%
#
#
#
#
# conda-24.11.3        | 1.1 MB    | 5                                     |   1%
# proj-9.3.1           | 3.2 MB    | #####################7                |  59%
#
# openssl-3.6.0        | 3.0 MB    | #################################1    |  90%
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ########7                             |  24%
#
#
#
#
#
# libstdcxx-15.2.0     | 5.6 MB    | ####################4                 |  55%
# proj-9.3.1           | 3.2 MB    | #########################             |  68%
#
#
#
# cartopy-0.25.0       | 1.5 MB    | ##################################### | 100%
#
#
#
#
# conda-24.11.3        | 1.1 MB    | #######################7              |  64%
#
#
#
#
#
# libstdcxx-15.2.0     | 5.6 MB    | ########################1             |  65%
# proj-9.3.1           | 3.2 MB    | ############################1         |  76%
#
#
#
#
#
#
# shapely-2.1.2        | 617 KB    | 9                                     |   3%
#
#
# geos-3.14.1          | 1.9 MB    | ##################################### | 100%
#
#
#
#
#
# libstdcxx-15.2.0     | 5.6 MB    | ###########################           |  73%
# proj-9.3.1           | 3.2 MB    | #################################6    |  91%
#
#
#
#
#
#
#
# libgomp-15.2.0       | 589 KB    | #                                     |   3%
#
# openssl-3.6.0        | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
#
# shapely-2.1.2        | 617 KB    | ####################1                 |  54%
#
#
#
#
#
# libstdcxx-15.2.0     | 5.6 MB    | ###############################4      |  85%
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 532 KB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
# pyshp-3.0.3          | 444 KB    | #3                                    |   4%
#
#
#
#
#
#
#
# libstdcxx-15.2.0     | 5.6 MB    | ####################################4 |  98%
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 532 KB    | ######################2               |  60%
#
#
#
#
#
# libgcc-15.2.0        | 1017 KB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | ###9                                  |  11%
#
#
#
#
#
#
#
#
#
#
# certifi-2025.11.12   | 153 KB    | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-15.2.0  | 26 KB     | ######################5               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.2.0     | 26 KB     | ######################5               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.12      | 6 KB      | ##################################### | 100%
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ##################################### | 100%
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
# shapely-2.1.2        | 617 KB    | ##################################### | 100%
#
#
#
#
#
#
# shapely-2.1.2        | 617 KB    | ##################################### | 100%
# proj-9.3.1           | 3.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# libgomp-15.2.0       | 589 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-15.2.0  | 26 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-15.2.0  | 26 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pyshp-3.0.3          | 444 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pyshp-3.0.3          | 444 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# certifi-2025.11.12   | 153 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# certifi-2025.11.12   | 153 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.2.0     | 26 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.2.0     | 26 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.12      | 6 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 532 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import cartopy.crs as ccrs

# %%
import xarray as xr
import pandas as pd
import numpy as np
import s3fs
import matplotlib.pyplot as plt
from pathlib import Path
from datetime import datetime, timedelta

# %%
fs = s3fs.S3FileSystem(anon=True)

# Directory with your C01 file
#deprecated (only one hour):
# prefix = "noaa-goes18/ABI-L2-CMIPF/2025/334/18/"
day_prefix = "noaa-goes18/ABI-L2-CMIPF/2025/334/"

hours = range(18, 24)
# List all files in that directory
#deprecated
# files = fs.ls(prefix)
#len(files), files[:5]
files = []
for h in hours:
    prefix = f"{day_prefix}{h:02d}/"
    files.extend(fs.ls(prefix))

print("Total files:", len(files))
# Out:
# Total files: 576

# %%
c13_files = [f for f in files if "M6C13" in f]
len(c13_files)
# Out:
# 36

# %%
# Sort them to be in time order
c13_files = sorted(c13_files)

# Pick a subset, e.g. every other file, or just first 6
#step = max(1, len(c13_files) // 6)
selected_files = c13_files#[::step][:6]

#selected_files
print("using", len(selected_files), "frames")
# Out:
# using 36 frames

# %%
def parse_goes_time_from_key(key):
    # key like "noaa-goes18/ABI-L2-CMIPF/2025/334/18/OR_ABI-L2-CMIPF-M6C13_G18_sYYYYJJJHHMMSS_e..."
    fname = key.split('/')[-1]
    s_index = fname.find('_s')
    e_index = fname.find('_e')
    timestr = fname[s_index+2:e_index]  # YYYYJJJHHMMSS
    year = int(timestr[0:4])
    jday = int(timestr[4:7])
    hour = int(timestr[7:9])
    minute = int(timestr[9:11])
    second = int(timestr[11:13])

    dt = datetime(year, 1, 1) + timedelta(days=jday-1, hours=hour, minutes=minute, seconds=second)
    return dt

# %%
import xarray as xr
import numpy as np
import pandas as pd
from pathlib import Path

# Pick the first C13 file
key0 = selected_files[0]
print("Using first file:", key0)

with fs.open(key0, mode="rb") as f:
    # Try h5netcdf first
    try:
        ds0 = xr.open_dataset(f, engine="h5netcdf")
    except Exception as e:
        print("h5netcdf failed, trying netcdf4:", e)
        f.seek(0)
        ds0 = xr.open_dataset(f, engine="netcdf4")

    # IMPORTANT: load everything into memory before leaving the 'with' block
    ds0.load()

# Now it's safe to work with ds0 outside the with-block
print(ds0)

CMI0 = ds0["CMI"]
print("CMI0 shape/dims:", CMI0.shape, CMI0.dims)

# Choose coarse grid size
n_rows = 50
n_cols = 50

ny, nx = CMI0.shape
fac_y = ny // n_rows
fac_x = nx // n_cols

CMI0_small = CMI0.coarsen(y=fac_y, x=fac_x, boundary="trim").mean()
print("Downsampled shape:", CMI0_small.shape)
# Out:
# Using first file: noaa-goes18/ABI-L2-CMIPF/2025/334/18/OR_ABI-L2-CMIPF-M6C13_G18_s20253341800214_e20253341809534_c20253341809590.nc
# <xarray.Dataset>
# Dimensions:                                           (y: 5424, x: 5424,
#                                                        number_of_time_bounds: 2,
#                                                        number_of_image_bounds: 2,
#                                                        band: 1)
# Coordinates:
#     t                                                 datetime64[ns] 2025-11-...
#   * y                                                 (y) float64 0.1518 ... ...
#   * x                                                 (x) float64 -0.1518 ......
#     y_image                                           float32 0.0
#     x_image                                           float32 0.0
#     band_wavelength                                   (band) float32 10.33
#     band_id                                           (band) int32 13
# Dimensions without coordinates: number_of_time_bounds, number_of_image_bounds,
#                                 band
# Data variables: (12/35)
#     CMI                                               (y, x) float32 nan ... nan
#     DQF                                               (y, x) float32 nan ... nan
#     time_bounds                                       (number_of_time_bounds) datetime64[ns] ...
#     goes_imager_projection                            int32 -2147483647
#     y_image_bounds                                    (number_of_image_bounds) float32 ...
#     x_image_bounds                                    (number_of_image_bounds) float32 ...
#     ...                                                ...
#     focal_plane_temperature_threshold_exceeded_count  float64 0.0
#     maximum_focal_plane_temperature                   float32 60.41
#     focal_plane_temperature_threshold_increasing      float32 100.0
#     focal_plane_temperature_threshold_decreasing      float32 101.0
#     channel_integration_time                          float64 nan
#     channel_gain_field                                float64 nan
# Attributes: (12/29)
#     naming_authority:          gov.nesdis.noaa
#     Conventions:               CF-1.7
#     Metadata_Conventions:      Unidata Dataset Discovery v1.0
#     standard_name_vocabulary:  CF Standard Name Table (v35, 20 July 2016)
#     institution:               DOC/NOAA/NESDIS > U.S. Department of Commerce,...
#     project:                   GOES
#     ...                        ...
#     cdm_data_type:             Image
#     time_coverage_start:       2025-11-30T18:00:21.4Z
#     time_coverage_end:         2025-11-30T18:09:53.4Z
#     timeline_id:               ABI Mode 6
#     production_data_source:    Realtime
#     id:                        fd8a58d3-6f3f-4443-922a-709eb24b9e94
# CMI0 shape/dims: (5424, 5424) ('y', 'x')
# Downsampled shape: (50, 50)

# %%
small_ny, small_nx = CMI0_small.shape
small_ny, small_nx

cells = []
cell_id = 0

for row in range(small_ny):
    for col in range(small_nx):
        x_norm = (col + 0.5) / small_nx
        y_norm = (row + 0.5) / small_ny
        width_norm = 1.0 / small_nx
        height_norm = 1.0 / small_ny

        cells.append({
            "cell_id": cell_id,
            "row": row,
            "col": col,
            "x_norm": x_norm,
            "y_norm": y_norm,
            "width_norm": width_norm,
            "height_norm": height_norm,
            "lat": np.nan,
            "lon": np.nan,
        })

        cell_id += 1

cells_df = pd.DataFrame(cells)
Path("data").mkdir(exist_ok=True)
cells_df.to_csv("data/cells.csv", index=False)
cells_df.head()
# Out:
#    cell_id  row  col  x_norm  y_norm  width_norm  height_norm  lat  lon
# 0        0    0    0    0.01    0.01        0.02         0.02  NaN  NaN
# 1        1    0    1    0.03    0.01        0.02         0.02  NaN  NaN
# 2        2    0    2    0.05    0.01        0.02         0.02  NaN  NaN
# 3        3    0    3    0.07    0.01        0.02         0.02  NaN  NaN
# 4        4    0    4    0.09    0.01        0.02         0.02  NaN  NaN

# %%
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

Path("images").mkdir(exist_ok=True)

def parse_goes_time_from_key(key):
    fname = key.split("/")[-1]
    s_index = fname.find("_s")
    e_index = fname.find("_e")
    timestr = fname[s_index+2:e_index]  # YYYYJJJHHMMSS
    year = int(timestr[0:4])
    jday = int(timestr[4:7])
    hour = int(timestr[7:9])
    minute = int(timestr[9:11])
    second = int(timestr[11:13])
    dt = datetime(year, 1, 1) + timedelta(days=jday-1, hours=hour, minutes=minute, seconds=second)
    return dt

times_rows = []
values_rows = []

for frame_index, key in enumerate(selected_files):
    print("Processing frame", frame_index, key)

    with fs.open(key, mode="rb") as f:
        # Try h5netcdf first
        try:
            ds = xr.open_dataset(f, engine="h5netcdf")
        except Exception as e:
            print("h5netcdf failed, trying netcdf4:", e)
            f.seek(0)
            ds = xr.open_dataset(f, engine="netcdf4")

        ds.load()  # load into memory

    CMI = ds["CMI"]

    # Use same fac_y/fac_x as computed from ds0
    CMI_small = CMI.coarsen(y=fac_y, x=fac_x, boundary="trim").mean()
    arr = CMI_small.values  # (small_ny, small_nx)

    # 1) Save PNG
    vmin = np.nanpercentile(arr, 2)
    vmax = np.nanpercentile(arr, 98)

    fig, ax = plt.subplots(figsize=(5, 5), dpi=180)
    ax.imshow(arr, origin="upper", cmap="inferno", vmin=vmin, vmax=vmax)
    ax.axis("off")

    img_name = f"goes_c13_frame_{frame_index:02d}.png"
    img_path = Path("images") / img_name
    fig.savefig(img_path, bbox_inches="tight", pad_inches=0)
    plt.close(fig)

    # 2) times.csv row
    dt = parse_goes_time_from_key(key)
    times_rows.append({
        "frame_index": frame_index,
        "time_iso": dt.isoformat() + "Z",
        "image_url": f"images/{img_name}",
    })

    # 3) values.csv rows
    for row in range(small_ny):
        for col in range(small_nx):
            cid = row * small_nx + col
            bt = float(arr[row, col]) if not np.isnan(arr[row, col]) else None
            values_rows.append({
                "frame_index": frame_index,
                "cell_id": cid,
                "brightness_temp": bt,
            })

times_df = pd.DataFrame(times_rows)
values_df = pd.DataFrame(values_rows)

times_df.to_csv("data/times.csv", index=False)
values_df.to_csv("data/values.csv", index=False)

times_df.head(), values_df.head()
# Out:
# Processing frame 0 noaa-goes18/ABI-L2-CMIPF/2025/334/18/OR_ABI-L2-CMIPF-M6C13_G18_s20253341800214_e20253341809534_c20253341809590.nc
# Processing frame 1 noaa-goes18/ABI-L2-CMIPF/2025/334/18/OR_ABI-L2-CMIPF-M6C13_G18_s20253341810214_e20253341819535_c20253341819593.nc
# Processing frame 2 noaa-goes18/ABI-L2-CMIPF/2025/334/18/OR_ABI-L2-CMIPF-M6C13_G18_s20253341820214_e20253341829535_c20253341829596.nc
# Processing frame 3 noaa-goes18/ABI-L2-CMIPF/2025/334/18/OR_ABI-L2-CMIPF-M6C13_G18_s20253341830214_e20253341839535_c20253341839591.nc
# Processing frame 4 noaa-goes18/ABI-L2-CMIPF/2025/334/18/OR_ABI-L2-CMIPF-M6C13_G18_s20253341840214_e20253341849536_c20253341849594.nc
# Processing frame 5 noaa-goes18/ABI-L2-CMIPF/2025/334/18/OR_ABI-L2-CMIPF-M6C13_G18_s20253341850214_e20253341859534_c20253341859590.nc
# Processing frame 6 noaa-goes18/ABI-L2-CMIPF/2025/334/19/OR_ABI-L2-CMIPF-M6C13_G18_s20253341900214_e20253341909535_c20253341909594.nc
# Processing frame 7 noaa-goes18/ABI-L2-CMIPF/2025/334/19/OR_ABI-L2-CMIPF-M6C13_G18_s20253341910214_e20253341919535_c20253341919599.nc
# Processing frame 8 noaa-goes18/ABI-L2-CMIPF/2025/334/19/OR_ABI-L2-CMIPF-M6C13_G18_s20253341920215_e20253341929535_c20253341929597.nc
# Processing frame 9 noaa-goes18/ABI-L2-CMIPF/2025/334/19/OR_ABI-L2-CMIPF-M6C13_G18_s20253341930215_e20253341939535_c20253341939597.nc
# Processing frame 10 noaa-goes18/ABI-L2-CMIPF/2025/334/19/OR_ABI-L2-CMIPF-M6C13_G18_s20253341940215_e20253341949535_c20253341949593.nc
# Processing frame 11 noaa-goes18/ABI-L2-CMIPF/2025/334/19/OR_ABI-L2-CMIPF-M6C13_G18_s20253341950215_e20253341959535_c20253341959595.nc
# Processing frame 12 noaa-goes18/ABI-L2-CMIPF/2025/334/20/OR_ABI-L2-CMIPF-M6C13_G18_s20253342000215_e20253342009535_c20253342009596.nc
# Processing frame 13 noaa-goes18/ABI-L2-CMIPF/2025/334/20/OR_ABI-L2-CMIPF-M6C13_G18_s20253342010215_e20253342019535_c20253342019593.nc
# Processing frame 14 noaa-goes18/ABI-L2-CMIPF/2025/334/20/OR_ABI-L2-CMIPF-M6C13_G18_s20253342020215_e20253342029534_c20253342029585.nc
# Processing frame 15 noaa-goes18/ABI-L2-CMIPF/2025/334/20/OR_ABI-L2-CMIPF-M6C13_G18_s20253342030215_e20253342039535_c20253342039586.nc
# Processing frame 16 noaa-goes18/ABI-L2-CMIPF/2025/334/20/OR_ABI-L2-CMIPF-M6C13_G18_s20253342040215_e20253342049535_c20253342049590.nc
# Processing frame 17 noaa-goes18/ABI-L2-CMIPF/2025/334/20/OR_ABI-L2-CMIPF-M6C13_G18_s20253342050215_e20253342059535_c20253342059594.nc
# Processing frame 18 noaa-goes18/ABI-L2-CMIPF/2025/334/21/OR_ABI-L2-CMIPF-M6C13_G18_s20253342100212_e20253342109533_c20253342109596.nc
# Processing frame 19 noaa-goes18/ABI-L2-CMIPF/2025/334/21/OR_ABI-L2-CMIPF-M6C13_G18_s20253342110212_e20253342119532_c20253342119598.nc
# Processing frame 20 noaa-goes18/ABI-L2-CMIPF/2025/334/21/OR_ABI-L2-CMIPF-M6C13_G18_s20253342120212_e20253342129532_c20253342129597.nc
# Processing frame 21 noaa-goes18/ABI-L2-CMIPF/2025/334/21/OR_ABI-L2-CMIPF-M6C13_G18_s20253342130212_e20253342139532_c20253342139595.nc
# Processing frame 22 noaa-goes18/ABI-L2-CMIPF/2025/334/21/OR_ABI-L2-CMIPF-M6C13_G18_s20253342140212_e20253342149533_c20253342149589.nc
# Processing frame 23 noaa-goes18/ABI-L2-CMIPF/2025/334/21/OR_ABI-L2-CMIPF-M6C13_G18_s20253342150212_e20253342159533_c20253342159594.nc
# Processing frame 24 noaa-goes18/ABI-L2-CMIPF/2025/334/22/OR_ABI-L2-CMIPF-M6C13_G18_s20253342200212_e20253342209533_c20253342209597.nc
# Processing frame 25 noaa-goes18/ABI-L2-CMIPF/2025/334/22/OR_ABI-L2-CMIPF-M6C13_G18_s20253342210212_e20253342219532_c20253342219589.nc
# Processing frame 26 noaa-goes18/ABI-L2-CMIPF/2025/334/22/OR_ABI-L2-CMIPF-M6C13_G18_s20253342220212_e20253342229532_c20253342229595.nc
# Processing frame 27 noaa-goes18/ABI-L2-CMIPF/2025/334/22/OR_ABI-L2-CMIPF-M6C13_G18_s20253342230212_e20253342239533_c20253342239591.nc
# Processing frame 28 noaa-goes18/ABI-L2-CMIPF/2025/334/22/OR_ABI-L2-CMIPF-M6C13_G18_s20253342240212_e20253342249532_c20253342249597.nc
# Processing frame 29 noaa-goes18/ABI-L2-CMIPF/2025/334/22/OR_ABI-L2-CMIPF-M6C13_G18_s20253342250212_e20253342259533_c20253342259599.nc
# Processing frame 30 noaa-goes18/ABI-L2-CMIPF/2025/334/23/OR_ABI-L2-CMIPF-M6C13_G18_s20253342300213_e20253342309533_c20253342309592.nc
# Processing frame 31 noaa-goes18/ABI-L2-CMIPF/2025/334/23/OR_ABI-L2-CMIPF-M6C13_G18_s20253342310213_e20253342319533_c20253342319577.nc
# Processing frame 32 noaa-goes18/ABI-L2-CMIPF/2025/334/23/OR_ABI-L2-CMIPF-M6C13_G18_s20253342320213_e20253342329533_c20253342329599.nc
# Processing frame 33 noaa-goes18/ABI-L2-CMIPF/2025/334/23/OR_ABI-L2-CMIPF-M6C13_G18_s20253342330213_e20253342339533_c20253342339590.nc
# Processing frame 34 noaa-goes18/ABI-L2-CMIPF/2025/334/23/OR_ABI-L2-CMIPF-M6C13_G18_s20253342340213_e20253342349533_c20253342349582.nc
# Processing frame 35 noaa-goes18/ABI-L2-CMIPF/2025/334/23/OR_ABI-L2-CMIPF-M6C13_G18_s20253342350213_e20253342359533_c20253342359586.nc
# (   frame_index              time_iso                     image_url
#  0            0  2025-11-30T18:00:21Z  images/goes_c13_frame_00.png
#  1            1  2025-11-30T18:10:21Z  images/goes_c13_frame_01.png
#  2            2  2025-11-30T18:20:21Z  images/goes_c13_frame_02.png
#  3            3  2025-11-30T18:30:21Z  images/goes_c13_frame_03.png
#  4            4  2025-11-30T18:40:21Z  images/goes_c13_frame_04.png,
#     frame_index  cell_id  brightness_temp
#  0            0        0              NaN
#  1            0        1              NaN
#  2            0        2              NaN
#  3            0        3              NaN
#  4            0        4              NaN)
